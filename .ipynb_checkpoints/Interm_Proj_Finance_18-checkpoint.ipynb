# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

import utils
import stock_data_fetcher
from stock_plotter import StockPlotter
from models import Models
from model_evaluator import ModelEvaluator
from time_series_visualizer import TimeSeriesVisualizer
from transformer_model import TimeSeriesTransformer
from lstm_transformer_model import LSTMTransformer
from backtest import BacktestStrategy

from matplotlib.backends.backend_pdf import PdfPages

# %% [markdown]
# #To get data from yfinance:
# ticker = "AAPL"
# start = "2020-01-01"
# end = "2025-01-01"
# interval = "1d"
#
# stock_fetcher = stock_data_fetcher.StockDataFetcher(ticker, start, end, interval)
# stock_data = stock_fetcher.fetch_data()

# %%
#To get data from pre-loaded csv file 
ticker = "AAPL"
start = "2022-01-01"
end = "2025-01-01"
stock_data = utils.get_csv(ticker, start, end)
print(stock_data.head()) 
print(ticker)
# Out:
# Loaded stock_data_csv\AAPL_2022-01-01_to_2025-01-01.csv successfully!
#          Date    Open    High     Low   Close      Volume
# 0  2024-12-31  252.44  253.28  249.43  250.42  39480718.0
# 1  2024-12-30  252.23  253.50  250.75  252.20  35557542.0
# 2  2024-12-27  257.83  258.70  253.06  255.59  42355321.0
# 3  2024-12-26  258.19  260.10  257.63  259.02  27262983.0
# 4  2024-12-24  255.49  258.21  255.29  258.20  23234705.0
# AAPL

# %%
pdf_path = f"results/results_{ticker}_{start}_to_{end}.pdf"
pdf_pages = PdfPages(pdf_path)

df = utils.add_technical_indicators(stock_data)

df_scaled, scaler = utils.prepare_features(df)
sequence_length = 15
X, y = utils.create_sequences(df_scaled[19:], sequence_length)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = np.array(X_train, dtype=np.float32)
y_train = np.array(y_train, dtype=np.float32)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'MACD', 'Signal',
#        'BB_upper', 'BB_middle', 'BB_lower'],
#       dtype='object')

# %%
#Draws plot
plotter = StockPlotter(stock_data, ticker)
fig1 = plotter.plot()
pdf_pages.savefig(fig1)  # Save stock plot to PDF

# %%
n_features = X_train.shape[2]
lstm_model = Models.LSTM_Model(sequence_length, n_features)
best_params = lstm_model.tune_hyperparameters(X_train, y_train)
history_lstm = lstm_model.fit(X_train, y_train, epochs=40, batch_size=32, validation_split=0.1)
y_pred_lstm = lstm_model.predict(X_test).flatten()
# Out:
# Reloading Tuner from lstm_tuner\lstm_hyperparameter_tuning\tuner0.json
# Epoch 1/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.3806 - val_loss: 0.0412
# Epoch 2/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0523 - val_loss: 0.0310
# Epoch 3/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0329 - val_loss: 0.0293
# Epoch 4/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0292 - val_loss: 0.0280
# Epoch 5/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0286 - val_loss: 0.0294
# Epoch 6/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0274 - val_loss: 0.0245
# Epoch 7/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0256 - val_loss: 0.0244
# Epoch 8/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0214 - val_loss: 0.0251
# Epoch 9/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0222 - val_loss: 0.0241
# Epoch 10/10
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0229 - val_loss: 0.0225
# Epoch 1/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0293 - val_loss: 0.0211
# Epoch 2/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0256 - val_loss: 0.0220
# Epoch 3/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0189 - val_loss: 0.0211
# Epoch 4/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0242 - val_loss: 0.0289
# Epoch 5/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0306 - val_loss: 0.0255
# Epoch 6/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0207 - val_loss: 0.0184
# Epoch 7/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0241 - val_loss: 0.0181
# Epoch 8/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0189 - val_loss: 0.0193
# Epoch 9/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 10/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0197 - val_loss: 0.0171
# Epoch 11/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0189 - val_loss: 0.0164
# Epoch 12/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0156 - val_loss: 0.0176
# Epoch 13/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0184 - val_loss: 0.0193
# Epoch 14/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0208 - val_loss: 0.0178
# Epoch 15/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0250 - val_loss: 0.0181
# Epoch 16/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0224 - val_loss: 0.0190
# Epoch 17/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0175 - val_loss: 0.0188
# Epoch 18/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0191 - val_loss: 0.0151
# Epoch 19/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0156 - val_loss: 0.0146
# Epoch 20/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0163 - val_loss: 0.0161
# Epoch 21/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0187 - val_loss: 0.0169
# Epoch 22/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0161 - val_loss: 0.0134
# Epoch 23/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0132 - val_loss: 0.0139
# Epoch 24/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0163 - val_loss: 0.0144
# Epoch 25/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0139 - val_loss: 0.0135
# Epoch 26/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0162 - val_loss: 0.0161
# Epoch 27/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0158 - val_loss: 0.0150
# Epoch 28/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0169 - val_loss: 0.0144
# Epoch 29/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0161 - val_loss: 0.0134
# Epoch 30/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0137 - val_loss: 0.0137
# Epoch 31/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0140 - val_loss: 0.0135
# Epoch 32/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0130 - val_loss: 0.0172
# Epoch 33/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0132 - val_loss: 0.0129
# Epoch 34/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0160 - val_loss: 0.0131
# Epoch 35/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0136 - val_loss: 0.0121
# Epoch 36/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0129 - val_loss: 0.0211
# Epoch 37/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0161 - val_loss: 0.0121
# Epoch 38/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0139 - val_loss: 0.0127
# Epoch 39/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0141 - val_loss: 0.0118
# Epoch 40/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0132 - val_loss: 0.0167
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
xgb_model = Models.XGB_Model(n_estimators=150, max_depth=8, learning_rate=0.05, gamma=0.3, subsample=0.9)

xgb_model.summary()  # ✅ Now the method exists and will print model details

xgb_model.fit(X_train, y_train)
predictions = xgb_model.predict(X_test)
y_pred_xgb = predictions.flatten()
# Out:
# 📌 **XGBoost Model Summary**
#  - n_estimators: 150
#  - max_depth: 8
#  - learning_rate: 0.05
#  - Other Parameters: {'gamma': 0.3, 'subsample': 0.9}
#  - Model Parameters: {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.3, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 8, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 150, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.9, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# [0]	validation_0-rmse:0.87559
# [1]	validation_0-rmse:0.83350
# [2]	validation_0-rmse:0.79334
# [3]	validation_0-rmse:0.75516
# [4]	validation_0-rmse:0.71880
# [5]	validation_0-rmse:0.68427
# [6]	validation_0-rmse:0.65157
# [7]	validation_0-rmse:0.62029
# [8]	validation_0-rmse:0.59044
# [9]	validation_0-rmse:0.56223
# [10]	validation_0-rmse:0.53546
# [11]	validation_0-rmse:0.50997
# [12]	validation_0-rmse:0.48581
# [13]	validation_0-rmse:0.46279
# [14]	validation_0-rmse:0.44095
# [15]	validation_0-rmse:0.42009
# [16]	validation_0-rmse:0.40037
# [17]	validation_0-rmse:0.38158
# [18]	validation_0-rmse:0.36389
# [19]	validation_0-rmse:0.34695
# [20]	validation_0-rmse:0.33076
# [21]	validation_0-rmse:0.31561
# [22]	validation_0-rmse:0.30116
# [23]	validation_0-rmse:0.28730
# [24]	validation_0-rmse:0.27405
# [25]	validation_0-rmse:0.26168
# [26]	validation_0-rmse:0.24985
# [27]	validation_0-rmse:0.23858
# [28]	validation_0-rmse:0.22797
# [29]	validation_0-rmse:0.21793
# [30]	validation_0-rmse:0.20842
# [31]	validation_0-rmse:0.19932
# [32]	validation_0-rmse:0.19073
# [33]	validation_0-rmse:0.18264
# [34]	validation_0-rmse:0.17483
# [35]	validation_0-rmse:0.16758
# [36]	validation_0-rmse:0.16077
# [37]	validation_0-rmse:0.15411
# [38]	validation_0-rmse:0.14804
# [39]	validation_0-rmse:0.14226
# [40]	validation_0-rmse:0.13672
# [41]	validation_0-rmse:0.13165
# [42]	validation_0-rmse:0.12669
# [43]	validation_0-rmse:0.12218
# [44]	validation_0-rmse:0.11791
# [45]	validation_0-rmse:0.11385
# [46]	validation_0-rmse:0.10994
# [47]	validation_0-rmse:0.10632
# [48]	validation_0-rmse:0.10300
# [49]	validation_0-rmse:0.09976
# [50]	validation_0-rmse:0.09679
# [51]	validation_0-rmse:0.09394
# [52]	validation_0-rmse:0.09135
# [53]	validation_0-rmse:0.08887
# [54]	validation_0-rmse:0.08642
# [55]	validation_0-rmse:0.08439
# [56]	validation_0-rmse:0.08239
# [57]	validation_0-rmse:0.08113
# [58]	validation_0-rmse:0.07942
# [59]	validation_0-rmse:0.07778
# [60]	validation_0-rmse:0.07626
# [61]	validation_0-rmse:0.07481
# [62]	validation_0-rmse:0.07391
# [63]	validation_0-rmse:0.07264
# [64]	validation_0-rmse:0.07181
# [65]	validation_0-rmse:0.07102
# [66]	validation_0-rmse:0.07028
# [67]	validation_0-rmse:0.06959
# [68]	validation_0-rmse:0.06892
# [69]	validation_0-rmse:0.06788
# [70]	validation_0-rmse:0.06729
# [71]	validation_0-rmse:0.06674
# [72]	validation_0-rmse:0.06621
# [73]	validation_0-rmse:0.06574
# [74]	validation_0-rmse:0.06524
# [75]	validation_0-rmse:0.06477
# [76]	validation_0-rmse:0.06477
# [77]	validation_0-rmse:0.06477
# [78]	validation_0-rmse:0.06433
# [79]	validation_0-rmse:0.06390
# [80]	validation_0-rmse:0.06390
# [81]	validation_0-rmse:0.06390
# [82]	validation_0-rmse:0.06390
# [83]	validation_0-rmse:0.06390
# [84]	validation_0-rmse:0.06390
# [85]	validation_0-rmse:0.06348
# [86]	validation_0-rmse:0.06348
# [87]	validation_0-rmse:0.06348
# [88]	validation_0-rmse:0.06348
# [89]	validation_0-rmse:0.06307
# [90]	validation_0-rmse:0.06307
# [91]	validation_0-rmse:0.06307
# [92]	validation_0-rmse:0.06307
# [93]	validation_0-rmse:0.06266
# [94]	validation_0-rmse:0.06266
# [95]	validation_0-rmse:0.06266
# [96]	validation_0-rmse:0.06266
# [97]	validation_0-rmse:0.06266
# [98]	validation_0-rmse:0.06266
# [99]	validation_0-rmse:0.06266
# [100]	validation_0-rmse:0.06266
# [101]	validation_0-rmse:0.06266
# [102]	validation_0-rmse:0.06266
# [103]	validation_0-rmse:0.06266
# [104]	validation_0-rmse:0.06266
# [105]	validation_0-rmse:0.06266
# [106]	validation_0-rmse:0.06266
# [107]	validation_0-rmse:0.06266
# [108]	validation_0-rmse:0.06266
# [109]	validation_0-rmse:0.06266
# [110]	validation_0-rmse:0.06266
# [111]	validation_0-rmse:0.06266
# [112]	validation_0-rmse:0.06266
# [113]	validation_0-rmse:0.06266
# [114]	validation_0-rmse:0.06266
# [115]	validation_0-rmse:0.06266
# [116]	validation_0-rmse:0.06266
# [117]	validation_0-rmse:0.06266
# [118]	validation_0-rmse:0.06266
# [119]	validation_0-rmse:0.06266
# [120]	validation_0-rmse:0.06266
# [121]	validation_0-rmse:0.06266
# [122]	validation_0-rmse:0.06266
# [123]	validation_0-rmse:0.06266
# [124]	validation_0-rmse:0.06266
# [125]	validation_0-rmse:0.06266
# [126]	validation_0-rmse:0.06266
# [127]	validation_0-rmse:0.06266
# [128]	validation_0-rmse:0.06266
# [129]	validation_0-rmse:0.06226
# [130]	validation_0-rmse:0.06227
# [131]	validation_0-rmse:0.06227
# [132]	validation_0-rmse:0.06227
# [133]	validation_0-rmse:0.06227
# [134]	validation_0-rmse:0.06227
# [135]	validation_0-rmse:0.06227
# [136]	validation_0-rmse:0.06227
# [137]	validation_0-rmse:0.06227
# [138]	validation_0-rmse:0.06227
# [139]	validation_0-rmse:0.06227
# [140]	validation_0-rmse:0.06227
# [141]	validation_0-rmse:0.06227
# [142]	validation_0-rmse:0.06227
# [143]	validation_0-rmse:0.06227
# [144]	validation_0-rmse:0.06227
# [145]	validation_0-rmse:0.06227
# [146]	validation_0-rmse:0.06227
# [147]	validation_0-rmse:0.06227
# [148]	validation_0-rmse:0.06227
# [149]	validation_0-rmse:0.06227

# %%
gp_model = Models.GP_Model()
gp_model.fit(X_train, y_train)

# Predict with confidence intervals
y_pred_gp, sigma_gp = gp_model.predict(X_test, return_std=True)
# Out:
# Optimized Kernel: 195**2 * Matern(length_scale=5e+03, nu=1.5) + WhiteKernel(noise_level=1e-09)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 5000. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-09. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
models = {
    'LSTM1': lstm_model,
    'XGBoost': xgb_model,
    'Gaussian Process': y_pred_gp
}
evaluator = ModelEvaluator(models, X_test, y_test, ticker)

# Evaluate models
evaluation_results, y_predictions = evaluator.evaluate()

# Print results
for model, metrics in evaluation_results.items():
    print(f"\nModel: {model}")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")

fig2 = evaluator.plot_metrics()
pdf_pages.savefig(fig2)
print(len(X_test))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# Model: LSTM1
# MSE: 0.3908
# MAE: 0.5067
# R²: 0.9137
# Direction: 0.4965
#
# Model: XGBoost
# MSE: 0.0040
# MAE: 0.0496
# R²: 0.9782
# Direction: 0.6923
#
# Model: Gaussian Process
# MSE: 0.0045
# MAE: 0.0519
# R²: 0.9758
# Direction: 0.6923
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 144

# %%
std_devs = {}  # Ensure std_devs exists even if sigma_gp is not available

if 'sigma_gp' in globals():
    std_devs['GP'] = sigma_gp  # Add Gaussian Process std deviation if available# Assuming you have predictions from LSTM, XGBoost, and Gaussian Process
    
'''predictions = {
    'LSTM': y_pred_lstm,
    'XGBoost': y_pred_xgb,
    'Gaussian Prpcess': y_pred_gp,
    'Transformer': y_pred_transformer
}'''
predictions = {
    'LSTM': y_pred_lstm,
    'XGBoost': y_pred_xgb,
    'Gaussian Process': y_pred_gp
}
if 'sigma_gp' in globals():
    std_devs = {'GP': sigma_gp}

visualizer = TimeSeriesVisualizer(y_test, predictions, ticker, std_devs)

fig3 = visualizer.plot_predictions()
pdf_pages.savefig(fig3)
fig4 = visualizer.compare_models()
pdf_pages.savefig(fig4)
# Out:
# C:\Users\aivis\AppData\Local\Temp\ipykernel_19720\2242802923.py:23: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig3)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
backtester = BacktestStrategy(initial_balance=10000, transaction_cost=0.001)

results_lstm = backtester.backtest(y_test, y_pred_lstm, model_name="LSTM")
metrics_lstm = backtester.evaluate_performance(results_lstm)
results_xgb = backtester.backtest(y_test, y_pred_xgb, model_name="XGBoost")
metrics_xgb = backtester.evaluate_performance(results_xgb)
results_gp = backtester.backtest(y_test, y_pred_xgb, model_name="Gaussian Process")
metrics_gp = backtester.evaluate_performance(results_gp)
# Out:
# Backtest for LSTM completed. Final balance: $-884.88
#
# Performance Metrics:
# Final Balance: -884.8836
# Total Return: -1.0885
# Sharpe Ratio: -0.0327
# Max Drawdown: 1.0431
# Backtest for XGBoost completed. Final balance: $-804.55
#
# Performance Metrics:
# Final Balance: -804.5523
# Total Return: -1.0805
# Sharpe Ratio: -0.0332
# Max Drawdown: 1.0431
# Backtest for Gaussian Process completed. Final balance: $-804.55
#
# Performance Metrics:
# Final Balance: -804.5523
# Total Return: -1.0805
# Sharpe Ratio: -0.0332
# Max Drawdown: 1.0431

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate individual figures
fig_lstm = backtester.plot_results(results_lstm, model_name="LSTM")
fig_xgb = backtester.plot_results(results_xgb, model_name="XGBoost")
fig_gp = backtester.plot_results(results_gp, model_name="Gaussian Process")

# Save figures to the PDF
pdf_pages.savefig(fig_lstm)
pdf_pages.savefig(fig_xgb)
pdf_pages.savefig(fig_gp)
print("Backtest results saved to PDF.")
# Out:
# Backtest results saved to PDF.

# %%
fig6 = utils.plot_training_history(history_lstm)  # Call only once and store result

if fig6 is not None:  # Ensure fig7 is valid before saving
    pdf_pages.savefig(fig6)
    print("Backtest results for LSTM saved to PDF (Page 6).")
else:
    print("Error: plot_training_history did not return a figure.")
# Out:
# Backtest results for LSTM saved to PDF (Page 6).

# %%
fig7 = xgb_model.plot_training_history(metric="rmse")
#fig7 = utils.plot_training_history(history_lstm)  # Call only once and store result

if fig7 is not None:  # Ensure fig7 is valid before saving
    pdf_pages.savefig(fig7)
    print("Backtest results for XGBoost saved to PDF (Page 7).")
else:
    print("Error: plot_training_history did not return a figure.")
# Out:
# Backtest results for XGBoost saved to PDF (Page 7).

# %%
#gp_model = GaussianProcessModel()
fig8 = gp_model.validate(X_train, y_train)
pdf_pages.savefig(fig8)  # ✅ Save to PDF
# Out:
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 5000. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-09. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Optimized Kernel: 192**2 * Matern(length_scale=5e+03, nu=1.5) + WhiteKernel(noise_level=1e-09)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-09. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 5000. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-09. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 5000. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-09. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 5000. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-09. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\_gpr.py:616: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 5000. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-09. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
# Close the PDF file
pdf_pages.close()
print(f"PDF successfully closed")

#Falls nur ein Teill von Code wird ausgefuert und kein pdf erzeugt wird, sonst Fehlermeldung
pdf_pages = PdfPages("output.pdf")

if pdf_pages.get_pagecount() > 0:  # Direkter Vergleich ohne len()
    pdf_pages.close()
else:
    pdf_pages._file.close()  # Datei korrekt schließen, um die Warnung zu vermeiden
# Out:
# PDF successfully closed
