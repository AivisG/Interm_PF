# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

import utils
import stock_data_fetcher
from stock_plotter import StockPlotter
from models import Models
from model_evaluator import ModelEvaluator
from time_series_visualizer import TimeSeriesVisualizer
from transformer_model import TimeSeriesTransformer
from lstm_transformer_model import LSTMTransformer
from backtest import BacktestStrategy

from matplotlib.backends.backend_pdf import PdfPages

# %% [markdown]
# #To get data from yfinance:
# ticker = "AAPL"
# start = "2020-01-01"
# end = "2025-01-01"
# interval = "1d"
#
# stock_fetcher = stock_data_fetcher.StockDataFetcher(ticker, start, end, interval)
# stock_data = stock_fetcher.fetch_data()

# %%
#To get data from pre-loaded csv file 
ticker = "AAPL"
start = "2024-07-01"
end = "2025-01-01"
stock_data = utils.get_csv(ticker, start, end)
print(stock_data.head()) 
print(ticker)
# Out:
# Loaded stock_data_csv\AAPL_2024-07-01_to_2025-01-01.csv successfully!
#          Date    Open    High     Low   Close      Volume
# 0  2024-12-31  252.44  253.28  249.43  250.42  39480718.0
# 1  2024-12-30  252.23  253.50  250.75  252.20  35557542.0
# 2  2024-12-27  257.83  258.70  253.06  255.59  42355321.0
# 3  2024-12-26  258.19  260.10  257.63  259.02  27262983.0
# 4  2024-12-24  255.49  258.21  255.29  258.20  23234705.0
# AAPL

# %%
pdf_path = f"results/results_{ticker}_{start}_to_{end}.pdf"
pdf_pages = PdfPages(pdf_path)

df = utils.add_technical_indicators(stock_data)

df_scaled, scaler = utils.prepare_features(df)
sequence_length = 15
X, y = utils.create_sequences(df_scaled[19:], sequence_length)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = np.array(X_train, dtype=np.float32)
y_train = np.array(y_train, dtype=np.float32)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'MACD', 'Signal',
#        'BB_upper', 'BB_middle', 'BB_lower'],
#       dtype='object')

# %%
#Draws plot
plotter = StockPlotter(stock_data, ticker)
fig1 = plotter.plot()
pdf_pages.savefig(fig1)  # Save stock plot to PDF
# Out:
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\1362725433.py:4: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig1)  # Save stock plot to PDF
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\1362725433.py:4: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig1)  # Save stock plot to PDF
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
n_features = X_train.shape[2]
lstm_model = Models.LSTM_Model(sequence_length, n_features)
best_params = lstm_model.tune_hyperparameters(X_train, y_train)
history_lstm = lstm_model.fit(X_train, y_train, epochs=40, batch_size=32, validation_split=0.1)
y_pred_lstm = lstm_model.predict(X_test).flatten()
# Out:
# Reloading Tuner from lstm_tuner\lstm_hyperparameter_tuning\tuner0.json
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - loss: 0.2678 - val_loss: 0.4862
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1130 - val_loss: 0.2783
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1387 - val_loss: 0.2394
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0991 - val_loss: 0.2488
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0874 - val_loss: 0.3913
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0870 - val_loss: 0.3263
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1046 - val_loss: 0.2496
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0872 - val_loss: 0.2009
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0588 - val_loss: 0.1863
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0786 - val_loss: 0.2178
# Epoch 1/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0601 - val_loss: 0.2604
# Epoch 2/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0794 - val_loss: 0.2924
# Epoch 3/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0957 - val_loss: 0.2330
# Epoch 4/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0702 - val_loss: 0.2019
# Epoch 5/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0864 - val_loss: 0.1733
# Epoch 6/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0652 - val_loss: 0.2402
# Epoch 7/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0667 - val_loss: 0.2803
# Epoch 8/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0608 - val_loss: 0.2388
# Epoch 9/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0604 - val_loss: 0.2560
# Epoch 10/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0704 - val_loss: 0.2651
# Epoch 11/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0567 - val_loss: 0.2408
# Epoch 12/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0586 - val_loss: 0.2458
# Epoch 13/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0586 - val_loss: 0.2421
# Epoch 14/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0599 - val_loss: 0.2134
# Epoch 15/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0601 - val_loss: 0.1987
# Epoch 16/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0745 - val_loss: 0.2058
# Epoch 17/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0599 - val_loss: 0.2157
# Epoch 18/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0657 - val_loss: 0.2336
# Epoch 19/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0737 - val_loss: 0.2713
# Epoch 20/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0622 - val_loss: 0.2577
# Epoch 21/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0529 - val_loss: 0.2420
# Epoch 22/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0507 - val_loss: 0.2431
# Epoch 23/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0604 - val_loss: 0.2636
# Epoch 24/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0713 - val_loss: 0.3188
# Epoch 25/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0737 - val_loss: 0.2152
# Epoch 26/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0655 - val_loss: 0.2130
# Epoch 27/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0715 - val_loss: 0.2259
# Epoch 28/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0507 - val_loss: 0.2589
# Epoch 29/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0627 - val_loss: 0.3260
# Epoch 30/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0642 - val_loss: 0.3963
# Epoch 31/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0579 - val_loss: 0.3401
# Epoch 32/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0539 - val_loss: 0.2244
# Epoch 33/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0726 - val_loss: 0.2268
# Epoch 34/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0831 - val_loss: 0.2508
# Epoch 35/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0763 - val_loss: 0.2428
# Epoch 36/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0511 - val_loss: 0.2467
# Epoch 37/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0533 - val_loss: 0.2468
# Epoch 38/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0618 - val_loss: 0.2453
# Epoch 39/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0540 - val_loss: 0.2336
# Epoch 40/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0572 - val_loss: 0.2382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step

# %%
xgb_model = Models.XGB_Model(n_estimators=150, max_depth=8, learning_rate=0.05, gamma=0.3, subsample=0.9)
xgb_model.summary()
xgb_model.fit(X_train, y_train)
predictions = xgb_model.predict(X_test)
y_pred_xgb = predictions.flatten()
##print(type(y_pred_xgb))
#print(y_pred_xgb)
# Out:
# XGBoost Model Config: {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.3, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 8, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 150, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.9, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# [0]	validation_0-rmse:0.54499
# [1]	validation_0-rmse:0.52328
# [2]	validation_0-rmse:0.50429
# [3]	validation_0-rmse:0.48436
# [4]	validation_0-rmse:0.46696
# [5]	validation_0-rmse:0.44938
# [6]	validation_0-rmse:0.43274
# [7]	validation_0-rmse:0.41703
# [8]	validation_0-rmse:0.40233
# [9]	validation_0-rmse:0.38944
# [10]	validation_0-rmse:0.37518
# [11]	validation_0-rmse:0.36337
# [12]	validation_0-rmse:0.35110
# [13]	validation_0-rmse:0.33916
# [14]	validation_0-rmse:0.32805
# [15]	validation_0-rmse:0.31669
# [16]	validation_0-rmse:0.30762
# [17]	validation_0-rmse:0.29851
# [18]	validation_0-rmse:0.28946
# [19]	validation_0-rmse:0.28142
# [20]	validation_0-rmse:0.27496
# [21]	validation_0-rmse:0.26764
# [22]	validation_0-rmse:0.25942
# [23]	validation_0-rmse:0.25240
# [24]	validation_0-rmse:0.24536
# [25]	validation_0-rmse:0.23936
# [26]	validation_0-rmse:0.23417
# [27]	validation_0-rmse:0.22897
# [28]	validation_0-rmse:0.22482
# [29]	validation_0-rmse:0.21898
# [30]	validation_0-rmse:0.21453
# [31]	validation_0-rmse:0.20975
# [32]	validation_0-rmse:0.20531
# [33]	validation_0-rmse:0.20248
# [34]	validation_0-rmse:0.19895
# [35]	validation_0-rmse:0.19557
# [36]	validation_0-rmse:0.19162
# [37]	validation_0-rmse:0.18775
# [38]	validation_0-rmse:0.18420
# [39]	validation_0-rmse:0.18095
# [40]	validation_0-rmse:0.17757
# [41]	validation_0-rmse:0.17563
# [42]	validation_0-rmse:0.17359
# [43]	validation_0-rmse:0.17182
# [44]	validation_0-rmse:0.16889
# [45]	validation_0-rmse:0.16709
# [46]	validation_0-rmse:0.16539
# [47]	validation_0-rmse:0.16357
# [48]	validation_0-rmse:0.16221
# [49]	validation_0-rmse:0.16061
# [50]	validation_0-rmse:0.15902
# [51]	validation_0-rmse:0.15758
# [52]	validation_0-rmse:0.15599
# [53]	validation_0-rmse:0.15476
# [54]	validation_0-rmse:0.15476
# [55]	validation_0-rmse:0.15349
# [56]	validation_0-rmse:0.15214
# [57]	validation_0-rmse:0.15213
# [58]	validation_0-rmse:0.15213
# [59]	validation_0-rmse:0.15087
# [60]	validation_0-rmse:0.14961
# [61]	validation_0-rmse:0.14961
# [62]	validation_0-rmse:0.14961
# [63]	validation_0-rmse:0.14961
# [64]	validation_0-rmse:0.14961
# [65]	validation_0-rmse:0.14961
# [66]	validation_0-rmse:0.14961
# [67]	validation_0-rmse:0.14961
# [68]	validation_0-rmse:0.14961
# [69]	validation_0-rmse:0.14962
# [70]	validation_0-rmse:0.14962
# [71]	validation_0-rmse:0.14962
# [72]	validation_0-rmse:0.14962
# [73]	validation_0-rmse:0.14961
# [74]	validation_0-rmse:0.14961
# [75]	validation_0-rmse:0.14961
# [76]	validation_0-rmse:0.14961
# [77]	validation_0-rmse:0.14961
# [78]	validation_0-rmse:0.14961
# [79]	validation_0-rmse:0.14961
# [80]	validation_0-rmse:0.14960
# [81]	validation_0-rmse:0.14960
# [82]	validation_0-rmse:0.14960
# [83]	validation_0-rmse:0.14960
# [84]	validation_0-rmse:0.14960
# [85]	validation_0-rmse:0.14960
# [86]	validation_0-rmse:0.14960
# [87]	validation_0-rmse:0.14960
# [88]	validation_0-rmse:0.14960
# [89]	validation_0-rmse:0.14960
# [90]	validation_0-rmse:0.14960
# [91]	validation_0-rmse:0.14960
# [92]	validation_0-rmse:0.14960
# [93]	validation_0-rmse:0.14960
# [94]	validation_0-rmse:0.14961
# [95]	validation_0-rmse:0.14961
# [96]	validation_0-rmse:0.14961
# [97]	validation_0-rmse:0.14961
# [98]	validation_0-rmse:0.14961
# [99]	validation_0-rmse:0.14961
# [100]	validation_0-rmse:0.14960
# [101]	validation_0-rmse:0.14960
# [102]	validation_0-rmse:0.14960
# [103]	validation_0-rmse:0.14960
# [104]	validation_0-rmse:0.14960
# [105]	validation_0-rmse:0.14960
# [106]	validation_0-rmse:0.14960
# [107]	validation_0-rmse:0.14960
# [108]	validation_0-rmse:0.14960
# [109]	validation_0-rmse:0.14960
# [110]	validation_0-rmse:0.14960
# [111]	validation_0-rmse:0.14960
# [112]	validation_0-rmse:0.14844
# [113]	validation_0-rmse:0.14844
# [114]	validation_0-rmse:0.14844
# [115]	validation_0-rmse:0.14844
# [116]	validation_0-rmse:0.14844
# [117]	validation_0-rmse:0.14844
# [118]	validation_0-rmse:0.14844
# [119]	validation_0-rmse:0.14844
# [120]	validation_0-rmse:0.14844
# [121]	validation_0-rmse:0.14844
# [122]	validation_0-rmse:0.14844
# [123]	validation_0-rmse:0.14844
# [124]	validation_0-rmse:0.14844
# [125]	validation_0-rmse:0.14844
# [126]	validation_0-rmse:0.14844
# [127]	validation_0-rmse:0.14844
# [128]	validation_0-rmse:0.14844
# [129]	validation_0-rmse:0.14844
# [130]	validation_0-rmse:0.14844
# [131]	validation_0-rmse:0.14844
# [132]	validation_0-rmse:0.14844
# [133]	validation_0-rmse:0.14844
# [134]	validation_0-rmse:0.14844
# [135]	validation_0-rmse:0.14844
# [136]	validation_0-rmse:0.14844
# [137]	validation_0-rmse:0.14844
# [138]	validation_0-rmse:0.14844
# [139]	validation_0-rmse:0.14844
# [140]	validation_0-rmse:0.14844
# [141]	validation_0-rmse:0.14844
# [142]	validation_0-rmse:0.14844
# [143]	validation_0-rmse:0.14844
# [144]	validation_0-rmse:0.14844
# [145]	validation_0-rmse:0.14844
# [146]	validation_0-rmse:0.14844
# [147]	validation_0-rmse:0.14844
# [148]	validation_0-rmse:0.14844
# [149]	validation_0-rmse:0.14844

# %%
xgb_model = Models.XGB_Model(n_estimators=150, max_depth=8, learning_rate=0.05, gamma=0.3, subsample=0.9)
xgb_model.summary()
xgb_model.fit(X_train, y_train, X_val=X_test, y_val=y_test)
predictions = xgb_model.predict(X_test)
y_pred_xgb = predictions.flatten()
##print(type(y_pred_xgb))
#print(y_pred_xgb)
# Out:
# XGBoost Model Config: {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.3, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 8, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 150, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.9, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# [0]	validation_0-rmse:0.54499	validation_1-rmse:0.50074
# [1]	validation_0-rmse:0.52328	validation_1-rmse:0.48283
# [2]	validation_0-rmse:0.50429	validation_1-rmse:0.46472
# [3]	validation_0-rmse:0.48436	validation_1-rmse:0.44952
# [4]	validation_0-rmse:0.46696	validation_1-rmse:0.43512
# [5]	validation_0-rmse:0.44938	validation_1-rmse:0.42471
# [6]	validation_0-rmse:0.43274	validation_1-rmse:0.40787
# [7]	validation_0-rmse:0.41703	validation_1-rmse:0.39589
# [8]	validation_0-rmse:0.40233	validation_1-rmse:0.38672
# [9]	validation_0-rmse:0.38944	validation_1-rmse:0.37882
# [10]	validation_0-rmse:0.37518	validation_1-rmse:0.36648
# [11]	validation_0-rmse:0.36337	validation_1-rmse:0.35572
# [12]	validation_0-rmse:0.35110	validation_1-rmse:0.34612
# [13]	validation_0-rmse:0.33916	validation_1-rmse:0.33606
# [14]	validation_0-rmse:0.32805	validation_1-rmse:0.32884
# [15]	validation_0-rmse:0.31669	validation_1-rmse:0.32119
# [16]	validation_0-rmse:0.30762	validation_1-rmse:0.31392
# [17]	validation_0-rmse:0.29851	validation_1-rmse:0.30562
# [18]	validation_0-rmse:0.28946	validation_1-rmse:0.30063
# [19]	validation_0-rmse:0.28142	validation_1-rmse:0.29585
# [20]	validation_0-rmse:0.27496	validation_1-rmse:0.29207
# [21]	validation_0-rmse:0.26764	validation_1-rmse:0.29021
# [22]	validation_0-rmse:0.25942	validation_1-rmse:0.28734
# [23]	validation_0-rmse:0.25240	validation_1-rmse:0.28225
# [24]	validation_0-rmse:0.24536	validation_1-rmse:0.27903
# [25]	validation_0-rmse:0.23936	validation_1-rmse:0.27760
# [26]	validation_0-rmse:0.23417	validation_1-rmse:0.27612
# [27]	validation_0-rmse:0.22897	validation_1-rmse:0.27564
# [28]	validation_0-rmse:0.22482	validation_1-rmse:0.27277
# [29]	validation_0-rmse:0.21898	validation_1-rmse:0.27327
# [30]	validation_0-rmse:0.21453	validation_1-rmse:0.27831
# [31]	validation_0-rmse:0.20975	validation_1-rmse:0.27595
# [32]	validation_0-rmse:0.20531	validation_1-rmse:0.27588
# [33]	validation_0-rmse:0.20248	validation_1-rmse:0.27454
# [34]	validation_0-rmse:0.19895	validation_1-rmse:0.27286
# [35]	validation_0-rmse:0.19557	validation_1-rmse:0.27479
# [36]	validation_0-rmse:0.19162	validation_1-rmse:0.27573
# [37]	validation_0-rmse:0.18775	validation_1-rmse:0.27862
# [38]	validation_0-rmse:0.18420	validation_1-rmse:0.28202
# [39]	validation_0-rmse:0.18095	validation_1-rmse:0.28585
# [40]	validation_0-rmse:0.17757	validation_1-rmse:0.28701
# [41]	validation_0-rmse:0.17563	validation_1-rmse:0.28643
# [42]	validation_0-rmse:0.17359	validation_1-rmse:0.28483
# [43]	validation_0-rmse:0.17182	validation_1-rmse:0.28789
# [44]	validation_0-rmse:0.16889	validation_1-rmse:0.29164
# [45]	validation_0-rmse:0.16709	validation_1-rmse:0.29121
# [46]	validation_0-rmse:0.16539	validation_1-rmse:0.29128
# [47]	validation_0-rmse:0.16357	validation_1-rmse:0.29437
# [48]	validation_0-rmse:0.16221	validation_1-rmse:0.29550
# [49]	validation_0-rmse:0.16061	validation_1-rmse:0.29469
# [50]	validation_0-rmse:0.15902	validation_1-rmse:0.29487
# [51]	validation_0-rmse:0.15758	validation_1-rmse:0.29558
# [52]	validation_0-rmse:0.15599	validation_1-rmse:0.29514
# [53]	validation_0-rmse:0.15476	validation_1-rmse:0.29440
# [54]	validation_0-rmse:0.15476	validation_1-rmse:0.29455
# [55]	validation_0-rmse:0.15349	validation_1-rmse:0.29462
# [56]	validation_0-rmse:0.15214	validation_1-rmse:0.29695
# [57]	validation_0-rmse:0.15213	validation_1-rmse:0.29733
# [58]	validation_0-rmse:0.15213	validation_1-rmse:0.29733
# [59]	validation_0-rmse:0.15087	validation_1-rmse:0.29643
# [60]	validation_0-rmse:0.14961	validation_1-rmse:0.29744
# [61]	validation_0-rmse:0.14961	validation_1-rmse:0.29732
# [62]	validation_0-rmse:0.14961	validation_1-rmse:0.29744
# [63]	validation_0-rmse:0.14961	validation_1-rmse:0.29768
# [64]	validation_0-rmse:0.14961	validation_1-rmse:0.29783
# [65]	validation_0-rmse:0.14961	validation_1-rmse:0.29782
# [66]	validation_0-rmse:0.14961	validation_1-rmse:0.29760
# [67]	validation_0-rmse:0.14961	validation_1-rmse:0.29752
# [68]	validation_0-rmse:0.14961	validation_1-rmse:0.29743
# [69]	validation_0-rmse:0.14962	validation_1-rmse:0.29713
# [70]	validation_0-rmse:0.14962	validation_1-rmse:0.29695
# [71]	validation_0-rmse:0.14962	validation_1-rmse:0.29708
# [72]	validation_0-rmse:0.14962	validation_1-rmse:0.29689
# [73]	validation_0-rmse:0.14961	validation_1-rmse:0.29747
# [74]	validation_0-rmse:0.14961	validation_1-rmse:0.29731
# [75]	validation_0-rmse:0.14961	validation_1-rmse:0.29734
# [76]	validation_0-rmse:0.14961	validation_1-rmse:0.29737
# [77]	validation_0-rmse:0.14961	validation_1-rmse:0.29753
# [78]	validation_0-rmse:0.14961	validation_1-rmse:0.29758
# [79]	validation_0-rmse:0.14961	validation_1-rmse:0.29775
# [80]	validation_0-rmse:0.14960	validation_1-rmse:0.29819
# [81]	validation_0-rmse:0.14960	validation_1-rmse:0.29825
# [82]	validation_0-rmse:0.14960	validation_1-rmse:0.29809
# [83]	validation_0-rmse:0.14960	validation_1-rmse:0.29803
# [84]	validation_0-rmse:0.14960	validation_1-rmse:0.29818
# [85]	validation_0-rmse:0.14960	validation_1-rmse:0.29811
# [86]	validation_0-rmse:0.14960	validation_1-rmse:0.29803
# [87]	validation_0-rmse:0.14960	validation_1-rmse:0.29805
# [88]	validation_0-rmse:0.14960	validation_1-rmse:0.29789
# [89]	validation_0-rmse:0.14960	validation_1-rmse:0.29798
# [90]	validation_0-rmse:0.14960	validation_1-rmse:0.29812
# [91]	validation_0-rmse:0.14960	validation_1-rmse:0.29819
# [92]	validation_0-rmse:0.14960	validation_1-rmse:0.29827
# [93]	validation_0-rmse:0.14960	validation_1-rmse:0.29806
# [94]	validation_0-rmse:0.14961	validation_1-rmse:0.29775
# [95]	validation_0-rmse:0.14961	validation_1-rmse:0.29754
# [96]	validation_0-rmse:0.14961	validation_1-rmse:0.29756
# [97]	validation_0-rmse:0.14961	validation_1-rmse:0.29754
# [98]	validation_0-rmse:0.14961	validation_1-rmse:0.29755
# [99]	validation_0-rmse:0.14961	validation_1-rmse:0.29778
# [100]	validation_0-rmse:0.14960	validation_1-rmse:0.29791
# [101]	validation_0-rmse:0.14960	validation_1-rmse:0.29812
# [102]	validation_0-rmse:0.14960	validation_1-rmse:0.29825
# [103]	validation_0-rmse:0.14960	validation_1-rmse:0.29837
# [104]	validation_0-rmse:0.14960	validation_1-rmse:0.29850
# [105]	validation_0-rmse:0.14960	validation_1-rmse:0.29839
# [106]	validation_0-rmse:0.14960	validation_1-rmse:0.29826
# [107]	validation_0-rmse:0.14960	validation_1-rmse:0.29828
# [108]	validation_0-rmse:0.14960	validation_1-rmse:0.29848
# [109]	validation_0-rmse:0.14960	validation_1-rmse:0.29819
# [110]	validation_0-rmse:0.14960	validation_1-rmse:0.29817
# [111]	validation_0-rmse:0.14960	validation_1-rmse:0.29826
# [112]	validation_0-rmse:0.14844	validation_1-rmse:0.29835
# [113]	validation_0-rmse:0.14844	validation_1-rmse:0.29832
# [114]	validation_0-rmse:0.14844	validation_1-rmse:0.29824
# [115]	validation_0-rmse:0.14844	validation_1-rmse:0.29812
# [116]	validation_0-rmse:0.14844	validation_1-rmse:0.29808
# [117]	validation_0-rmse:0.14844	validation_1-rmse:0.29805
# [118]	validation_0-rmse:0.14844	validation_1-rmse:0.29819
# [119]	validation_0-rmse:0.14844	validation_1-rmse:0.29827
# [120]	validation_0-rmse:0.14844	validation_1-rmse:0.29789
# [121]	validation_0-rmse:0.14844	validation_1-rmse:0.29784
# [122]	validation_0-rmse:0.14844	validation_1-rmse:0.29804
# [123]	validation_0-rmse:0.14844	validation_1-rmse:0.29800
# [124]	validation_0-rmse:0.14844	validation_1-rmse:0.29774
# [125]	validation_0-rmse:0.14844	validation_1-rmse:0.29785
# [126]	validation_0-rmse:0.14844	validation_1-rmse:0.29803
# [127]	validation_0-rmse:0.14844	validation_1-rmse:0.29781
# [128]	validation_0-rmse:0.14844	validation_1-rmse:0.29763
# [129]	validation_0-rmse:0.14844	validation_1-rmse:0.29762
# [130]	validation_0-rmse:0.14844	validation_1-rmse:0.29749
# [131]	validation_0-rmse:0.14844	validation_1-rmse:0.29752
# [132]	validation_0-rmse:0.14844	validation_1-rmse:0.29769
# [133]	validation_0-rmse:0.14844	validation_1-rmse:0.29775
# [134]	validation_0-rmse:0.14844	validation_1-rmse:0.29752
# [135]	validation_0-rmse:0.14844	validation_1-rmse:0.29745
# [136]	validation_0-rmse:0.14844	validation_1-rmse:0.29751
# [137]	validation_0-rmse:0.14844	validation_1-rmse:0.29761
# [138]	validation_0-rmse:0.14844	validation_1-rmse:0.29753
# [139]	validation_0-rmse:0.14844	validation_1-rmse:0.29756
# [140]	validation_0-rmse:0.14844	validation_1-rmse:0.29754
# [141]	validation_0-rmse:0.14844	validation_1-rmse:0.29753
# [142]	validation_0-rmse:0.14844	validation_1-rmse:0.29768
# [143]	validation_0-rmse:0.14844	validation_1-rmse:0.29781
# [144]	validation_0-rmse:0.14844	validation_1-rmse:0.29784
# [145]	validation_0-rmse:0.14844	validation_1-rmse:0.29770
# [146]	validation_0-rmse:0.14844	validation_1-rmse:0.29793
# [147]	validation_0-rmse:0.14844	validation_1-rmse:0.29778
# [148]	validation_0-rmse:0.14844	validation_1-rmse:0.29761
# [149]	validation_0-rmse:0.14844	validation_1-rmse:0.29768

# %% [markdown]
# gp_model = Models.GP_Model()
# gp_model.fit(X_train, y_train)
#
# # Predict with confidence intervals
# y_pred_gp, sigma_gp = gp_model.predict(X_test, return_std=True)
#
# # Print predictions and standard deviation (sigma)
# ##print("Type of y_pred_gp:", type(y_pred_gp))
# ##print("Predictions:", y_pred_gp)
# ##print("Sigma (Uncertainty):", sigma_gp)

# %% [markdown]
# # Define input feature size dynamically from X_train
# input_feature_size = X_train.shape[-1]  # Extracts the number of features
#
# transformer_model = LSTMTransformer(
#     num_layers=4,
#     d_model=input_feature_size,  # Set `d_model` to the number of input features
#     num_heads=8,
#     dff=512,
#     input_seq_len=20
# )
#
# projection_layer = tf.keras.layers.Dense(input_feature_size)  # Use `input_feature_size`
# X_test_transformed = projection_layer(X_test)
#
# y_pred_transformer = transformer_model(X_test_transformed)
#
# print("Predicted Output Shape:", y_pred_transformer.shape)  # Expected: (10, 1)

# %%
models = {
    'LSTM1': lstm_model,
    'XGBoost': xgb_model  
}
evaluator = ModelEvaluator(models, X_test, y_test, ticker)

# Evaluate models
evaluation_results, y_predictions = evaluator.evaluate()

# Print results
for model, metrics in evaluation_results.items():
    print(f"\nModel: {model}")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")

fig2 = evaluator.plot_metrics()
pdf_pages.savefig(fig2)
print(len(X_test))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Model: LSTM1
# MSE: 0.5771
# MAE: 0.6064
# R²: -0.0133
# Direction: 0.5370
#
# Model: XGBoost
# MSE: 0.0886
# MAE: 0.2239
# R²: 0.6729
# Direction: 0.6667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\3260165987.py:17: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig2)
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\3260165987.py:17: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig2)
# 19
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
std_devs = {}  # Ensure std_devs exists even if sigma_gp is not available

if 'sigma_gp' in globals():
    std_devs['GP'] = sigma_gp  # Add Gaussian Process std deviation if available# Assuming you have predictions from LSTM, XGBoost, and Gaussian Process
    
'''predictions = {
    'LSTM': y_pred_lstm,
    'XGBoost': y_pred_xgb,
    'GP': y_pred_gp,
    'Transformer': y_pred_transformer
}'''
predictions = {
    'LSTM': y_pred_lstm,
    'XGBoost': y_pred_xgb
}
if 'sigma_gp' in globals():
    std_devs = {'GP': sigma_gp}

visualizer = TimeSeriesVisualizer(y_test, predictions, ticker, std_devs)

fig3 = visualizer.plot_predictions()
pdf_pages.savefig(fig3)
fig4 = visualizer.compare_models()
pdf_pages.savefig(fig4)
# Out:
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\116737962.py:22: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig3)
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\116737962.py:22: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig3)
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\116737962.py:24: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig4)
# C:\Users\aivis\AppData\Local\Temp\ipykernel_8200\116737962.py:24: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   pdf_pages.savefig(fig4)

# %%
backtester = BacktestStrategy(initial_balance=10000, transaction_cost=0.001)

results_lstm = backtester.backtest(y_test, y_pred_lstm, model_name="LSTM")
metrics_lstm = backtester.evaluate_performance(results_lstm)
results_xgb = backtester.backtest(y_test, y_pred_xgb, model_name="XGBoost")
metrics_xgb = backtester.evaluate_performance(results_xgb)
# Out:
# Backtest for LSTM completed. Final balance: $11030.59
#
# Performance Metrics:
# Final Balance: 11030.5903
# Total Return: 0.1031
# Sharpe Ratio: -0.3665
# Max Drawdown: 1.3377
# Backtest for XGBoost completed. Final balance: $11603.28
#
# Performance Metrics:
# Final Balance: 11603.2796
# Total Return: 0.1603
# Sharpe Ratio: -0.3651
# Max Drawdown: 1.2567

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate individual figures
fig_lstm = backtester.plot_results(results_lstm, model_name="LSTM")
fig_xgb = backtester.plot_results(results_xgb, model_name="XGBoost")

# Create a new figure with two subplots
fig5, axes = plt.subplots(1, 2, figsize=(18, 8))  # Two columns

# Convert figures to images (renders them in memory)
fig_lstm.canvas.draw()
fig_xgb.canvas.draw()

# Convert figures to numpy arrays
lstm_img = np.array(fig_lstm.canvas.renderer.buffer_rgba())
xgb_img = np.array(fig_xgb.canvas.renderer.buffer_rgba())

# Display the images in subplots
axes[0].imshow(lstm_img)
axes[1].imshow(xgb_img)

# Remove axis ticks and labels
axes[0].axis("off")
axes[1].axis("off")

# Set titles manually
axes[0].set_title("LSTM Backtest Results", fontsize=14)
axes[1].set_title("XGBoost Backtest Results", fontsize=14)

# Adjust layout
plt.tight_layout()

pdf_pages.savefig(fig_lstm)
pdf_pages.savefig(fig_xgb)
# Save the combined figure to the PDF
pdf_pages.savefig(fig5)
print("Combined backtest results for LSTM and XGBoost saved to PDF.")
# Out:
# Combined backtest results for LSTM and XGBoost saved to PDF.

# %%
fig6 = utils.plot_training_history(history_lstm)  # Call only once and store result

if fig6 is not None:  # Ensure fig7 is valid before saving
    pdf_pages.savefig(fig6)
    print("Backtest results for LSTM saved to PDF (Page 6).")
else:
    print("Error: plot_training_history did not return a figure.")
# Out:
# Backtest results for LSTM saved to PDF (Page 6).

# %%
fig7 = xgb_model.plot_training_history(metric="rmse")
#fig7 = utils.plot_training_history(history_lstm)  # Call only once and store result

if fig7 is not None:  # Ensure fig7 is valid before saving
    pdf_pages.savefig(fig7)
    print("Backtest results for XGBoost saved to PDF (Page 7).")
else:
    print("Error: plot_training_history did not return a figure.")
# Out:
# Backtest results for XGBoost saved to PDF (Page 7).

# %%
# Close the PDF file
pdf_pages.close()
print(f"PDF successfully closed")

#Falls nur ein Teill von Code wird ausgefuert und kein pdf erzeugt wird, sonst Fehlermeldung
pdf_pages = PdfPages("output.pdf")

if pdf_pages.get_pagecount() > 0:  # Direkter Vergleich ohne len()
    pdf_pages.close()
else:
    pdf_pages._file.close()  # Datei korrekt schließen, um die Warnung zu vermeiden
# Out:
# PDF successfully closed
