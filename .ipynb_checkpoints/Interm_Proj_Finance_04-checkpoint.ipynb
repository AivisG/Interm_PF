# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

import utils
import stock_data_fetcher
from stock_plotter import StockPlotter
from models import Models
from model_evaluator import ModelEvaluator
from time_series_visualizer import TimeSeriesVisualizer
from transformer_model import TimeSeriesTransformer

# %% [markdown]
# # from csv file
# stock_data = pd.read_csv("uber.csv")
# print(stock_data.head())
# ticker = "uber(csv)"
# print(ticker)

# %%
ticker = "AAPL"
start = "2012-01-01"
end = "2024-04-01" 
interval = "1d"

# %%
if __name__ == "__main__":
    stock_fetcher = stock_data_fetcher.StockDataFetcher(ticker, start, end, interval)
    stock_data = stock_fetcher.fetch_data()    
    ##print(stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = utils.add_technical_indicators(stock_data)
print(df)

# Bereite die Daten vor
df_scaled, scaler = utils.prepare_features(df)
##print(df_scaled.head(21), type(df_scaled))
##print(df_scaled.columns)

sequence_length = 20 
X, y = utils.create_sequences(df_scaled[19:], sequence_length)

train_size = int(len(X) * 0.8) # Zeitbasiertes Splitting
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = np.array(X_train, dtype=np.float32)
y_train = np.array(y_train, dtype=np.float32)
##print(ticker)
# Out:
#                  Close        High         Low        Open     Volume  \
# Date
# 2012-01-03   12.388997   12.427258   12.321815   12.333866  302220800
# 2012-01-04   12.455575   12.492933   12.330248   12.351939  260022000
# 2012-01-05   12.593857   12.609522   12.432377   12.501067  271269600
# 2012-01-06   12.725513   12.736057   12.629710   12.646280  318292800
# 2012-01-09   12.705328   12.886691   12.693880   12.818906  394024400
# ...                ...         ...         ...         ...        ...
# 2024-03-22  171.658875  172.426103  169.446877  171.140745   71106600
# 2024-03-25  170.234039  171.320106  168.839078  169.955050   54288300
# 2024-03-26  169.098145  170.801971  168.968608  169.387092   57388400
# 2024-03-27  172.685165  172.974128  169.496705  169.795627   60273300
# 2024-03-28  170.861755  171.609051  169.895251  171.130786   65672700
#
#                    RSI      MACD    Signal    BB_upper   BB_middle    BB_lower
# Date
# 2012-01-03         NaN  0.000000  0.000000         NaN         NaN         NaN
# 2012-01-04  100.000000  0.005311  0.001062         NaN         NaN         NaN
# 2012-01-05  100.000000  0.020443  0.004938         NaN         NaN         NaN
# 2012-01-06  100.000000  0.042567  0.012464         NaN         NaN         NaN
# 2012-01-09   94.341318  0.057806  0.021533         NaN         NaN         NaN
# ...                ...       ...       ...         ...         ...         ...
# 2024-03-22   45.127840 -2.545997 -3.044688  182.926424  174.097050  165.267675
# 2024-03-25   51.437608 -2.611040 -2.957959  182.029655  173.583409  165.137163
# 2024-03-26   51.155537 -2.722856 -2.910938  180.621993  172.939738  165.257484
# 2024-03-27   57.428496 -2.493288 -2.827408  179.277268  172.535700  165.794133
# 2024-03-28   51.288221 -2.430471 -2.748021  177.827118  172.073871  166.320624
#
# [3079 rows x 11 columns]
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'RSI', 'MACD', 'Signal',
#        'BB_upper', 'BB_middle', 'BB_lower'],
#       dtype='object')

# %%
plotter = StockPlotter(stock_data, "AAPL")
plotter.plot()

# %%
# Define input shape
sequence_length = 20
n_features = X_train.shape[2]
lstm_model = Models.LSTM_Model(sequence_length, n_features)
# Tune hyperparameters
best_params = lstm_model.tune_hyperparameters(X_train, y_train)
##print("Best Hyperparameters Found:", best_params.values)
# Train with the best hyperparameters
history = lstm_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1)
predictions = lstm_model.predict(X_test)
y_pred_lstm = predictions.flatten()
##print(type(y_pred_lstm))
##print(y_pred_lstm)
# Out:
# Reloading Tuner from lstm_tuner\lstm_hyperparameter_tuning\tuner0.json
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0484 - val_loss: 0.0389
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0086 - val_loss: 0.0217
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0072 - val_loss: 0.0222
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0068 - val_loss: 0.0329
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0058 - val_loss: 0.0092
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0047 - val_loss: 0.0188
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0046 - val_loss: 0.0235
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0048 - val_loss: 0.0117
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0045 - val_loss: 0.0143
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0038 - val_loss: 0.0125
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0045 - val_loss: 0.0339
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0040 - val_loss: 0.0063
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0036 - val_loss: 0.0327
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0036 - val_loss: 0.0150
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - val_loss: 0.0166
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - val_loss: 0.0080
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
xgb_model = Models.XGB_Model(n_estimators=150, max_depth=8, learning_rate=0.05, gamma=0.3, subsample=0.9)
xgb_model.summary()
xgb_model.fit(X_train, y_train)
predictions = xgb_model.predict(X_test)
y_pred_xgb = predictions.flatten()
##print(type(y_pred_xgb))
##print(y_pred_xgb)
# Out:
# XGBoost Model Config: {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': 0.3, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 8, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 150, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.9, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}

# %%
gp_model = Models.GP_Model()
gp_model.fit(X_train, y_train)

# Predict with confidence intervals
y_pred_gp, sigma_gp = gp_model.predict(X_test, return_std=True)

# Print predictions and standard deviation (sigma)
##print("Type of y_pred_gp:", type(y_pred_gp))
##print("Predictions:", y_pred_gp)
##print("Sigma (Uncertainty):", sigma_gp)
# Out:
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 5000. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\aivis\anaconda3\envs\tf_env\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Optimized Kernel: 65.5**2 * Matern(length_scale=5e+03, nu=1.5) + WhiteKernel(noise_level=1e-05)

# %%
# Define input feature size dynamically from X_train
input_feature_size = X_train.shape[-1]  # Extracts the number of features

transformer_model = TimeSeriesTransformer(
    num_layers=4,
    d_model=input_feature_size,  # Set `d_model` to the number of input features
    num_heads=8,
    dff=512,
    input_seq_len=20,
    target_seq_len=1
)

projection_layer = tf.keras.layers.Dense(input_feature_size)  # Use `input_feature_size`
X_test_transformed = projection_layer(X_test)

y_pred_transformer = transformer_model(X_test_transformed)

print("Predicted Output Shape:", y_pred_transformer.shape)  # Expected: (10, 1)
# Out:
# Predicted Output Shape: (608, 1)

# %%
models = {
    'LSTM': lstm_model,
    'XGBoost': xgb_model,
    'Gaussian Process': gp_model,
    'Transformer': transformer_model
}   
evaluator = ModelEvaluator(models, X_test, y_test, ticker)
evaluation_results, y_predictions = evaluator.evaluate()
# Print results
for model, metrics in evaluation_results.items():
    print(f"\nModel: {model}")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")
# Plot metrics
evaluator.plot_metrics()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Model: LSTM
# MSE, lower is better: 0.0537
# MAE, lower is better: 0.2015
# R², higher is better: 0.4188
# Direction Accuracy, above 0.5 is better: 0.5074
#
# Model: XGBoost
# MSE, lower is better: 0.2374
# MAE, lower is better: 0.4028
# R², higher is better: -1.5708
# Direction Accuracy, above 0.5 is better: 0.0708
#
# Model: Gaussian Process
# MSE, lower is better: 0.0033
# MAE, lower is better: 0.0452
# R², higher is better: 0.9645
# Direction Accuracy, above 0.5 is better: 0.5025
#
# Model: Transformer
# MSE, lower is better: 0.2492
# MAE, lower is better: 0.4254
# R², higher is better: -1.6980
# Direction Accuracy, above 0.5 is better: 0.5091

# %%
# Assuming you have predictions from LSTM, XGBoost, and Gaussian Process
predictions = {
    'LSTM': y_pred_lstm,
    'XGBoost': y_pred_xgb,
    'GP': y_pred_gp,
    'Transformer': y_pred_transformer
}
std_devs = {'GP': sigma_gp}  # Only Gaussian Process provides true std deviation
# Initialize visualizer
visualizer = TimeSeriesVisualizer(y_test, predictions, ticker, std_devs)
# Correct way to plot all models in subplots
visualizer.plot_predictions()  # ✔️ Works without arguments
# Compare all models in a single plot
visualizer.compare_models()
